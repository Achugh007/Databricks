# %% [markdown]
# # Using Azure Databricks Notebooks with SQL for Data Processing

# %% [markdown]
# ## Exploring Databases and Tables

# %%
# %sql
SHOW TABLES;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql 
SHOW TABLES FROM default;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql 
SHOW TABLES IN default LIKE 'day6*'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>day6data_1_csv</td><td>false</td></tr></tbody></table></div>

# %% [markdown]
# ## Creating database and tables

# %%
# %sql 
CREATE DATABASE IF NOT EXISTS SparkSQLDB COMMENT 'This is a sample database for SparkSQL Lab' LOCATION '/user';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Check the information about database

# %%
# %sql
DESCRIBE DATABASE EXTENDED SparkSQLDB;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database_description_item</th><th>database_description_value</th></tr></thead><tbody><tr><td>Catalog Name</td><td>hive_metastore</td></tr><tr><td>Namespace Name</td><td>SparkSQLDB</td></tr><tr><td>Comment</td><td>This is a sample database for SparkSQL Lab</td></tr><tr><td>Location</td><td>dbfs:/user</td></tr><tr><td>Owner</td><td>root</td></tr><tr><td>Properties</td><td></td></tr></tbody></table></div>

# %% [markdown]
# We will create a table for the csv file.
# We will be using CSV file which is available on location dbfs:/FileStore/tables/temp.csv
# This dataset has three columns (Date, Temperature and City) and it should be good starting example.

# %%
# %sql
USE SparkSQLDB;

DROP TABLE IF EXISTS temperature;
CREATE TABLE temperature (date STRING, mean_daily_temp STRING, city STRING)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
USE SparkSQLDB;

SELECT * FROM temperature
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>mean_daily_temp</th><th>city</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SHOW TABLES IN SparkSQLDB;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>sparksqldb</td><td>temperature</td><td>false</td></tr></tbody></table></div>

# %%
# %sql
USE SparkSQLDB;

DROP VIEW IF EXISTS temp_view1;
CREATE TEMPORARY VIEW temp_view1
USING CSV
OPTIONS (path "/FileStore/tables/temp.csv", header "true", mode "FAILFAST")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
USE SparkSQLDB;
SELECT * FROM temp_view1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>mean_daily_temp</th><th>city</th></tr></thead><tbody><tr><td>05/12/2020</td><td>1</td><td>Ljubljana</td></tr><tr><td>06/12/2020</td><td>2</td><td>Ljubljana</td></tr><tr><td>07/12/2020</td><td>2</td><td>Ljubljana</td></tr><tr><td>08/12/2020</td><td>1</td><td>Ljubljana</td></tr><tr><td>09/12/2020</td><td>-1</td><td>Ljubljana</td></tr><tr><td>10/12/2020</td><td>-2</td><td>Ljubljana</td></tr><tr><td>11/12/2020</td><td>0</td><td>Ljubljana</td></tr><tr><td>12/12/2020</td><td>1</td><td>Ljubljana</td></tr><tr><td>13/12/2020</td><td>2</td><td>Ljubljana</td></tr><tr><td>14/12/2020</td><td>3</td><td>Ljubljana</td></tr><tr><td>05/12/2020</td><td>6</td><td>Seattle</td></tr><tr><td>06/12/2020</td><td>7</td><td>Seattle</td></tr><tr><td>07/12/2020</td><td>6</td><td>Seattle</td></tr><tr><td>08/12/2020</td><td>5</td><td>Seattle</td></tr><tr><td>09/12/2020</td><td>6</td><td>Seattle</td></tr><tr><td>10/12/2020</td><td>7</td><td>Seattle</td></tr><tr><td>11/12/2020</td><td>9</td><td>Seattle</td></tr><tr><td>12/12/2020</td><td>10</td><td>Seattle</td></tr><tr><td>13/12/2020</td><td>3</td><td>Seattle</td></tr><tr><td>14/12/2020</td><td>4</td><td>Seattle</td></tr></tbody></table></div>

# %%
# %sql
USE SparkSQLDB;
INSERT INTO temperature TABLE temp_view1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>20</td><td>20</td></tr></tbody></table></div>

# %% [markdown]
# Check the data types using DESCRIBE clause

# %%
# %sql
DESCRIBE temperature
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>date</td><td>string</td><td>null</td></tr><tr><td>mean_daily_temp</td><td>string</td><td>null</td></tr><tr><td>city</td><td>string</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE temp_view1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>date</td><td>string</td><td>null</td></tr><tr><td>mean_daily_temp</td><td>string</td><td>null</td></tr><tr><td>city</td><td>string</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# ### Now create two tables and crete a join

# %%
# %sql
USE SparkSQLDB;

DROP TABLE IF EXISTS temp1;
DROP TABLE IF EXISTS temp2;


CREATE TABLE temp1 (id_t1 INT, name STRING, temperature INT);
CREATE TABLE temp2 (id_t2 INT, name STRING, temperature INT);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
USE SparkSQLDB;

INSERT INTO temp1 VALUES    (2, 'Ljubljana', 1);
INSERT INTO temp1 VALUES    (3, 'Seattle', 5);
INSERT INTO temp2 VALUES    (1, 'Ljubljana', -3);
INSERT INTO temp2 VALUES    (2, 'Seattle`', 3);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
USE SparkSQLDB;

SELECT 
t1.Name as City1
,t2.Name AS City2
,t1.temperature*t2.Temperature AS MultipliedTemperature

FROM temp1 AS t1
JOIN temp2 AS t2
ON t1.id_t1 = t2.id_t2
WHERE 
t1.name <> t2.name
LIMIT 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>City1</th><th>City2</th><th>MultipliedTemperature</th></tr></thead><tbody><tr><td>Ljubljana</td><td>Seattle`</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
SHOW COLUMNS IN temp1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th></tr></thead><tbody><tr><td>id_t1</td></tr><tr><td>name</td></tr><tr><td>temperature</td></tr></tbody></table></div>
